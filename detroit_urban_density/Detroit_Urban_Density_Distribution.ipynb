# %%
import pandas as pd
import pylab as pl
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#UPDATE THIS PATH WITH THE PATH TO WHERE THE DOCUMENT LIVES ON YOUR COMPUTER
path = '/Users/carlyle/Documents/urban_sys/detroit/'

# %%
# https://www.census.gov/population/metro/data/pop_pro.html
#cities with pops 1-2.5 million, density as a distance from city center
df = pd.read_csv(path + 'detroit_graph_pandas.csv', thousands=',')

# %%
det = df['Detroit-Warren-Livonia, MI Metro Area']

# %%
#det = det.convert_objects(convert_numeric=True)

# %%
det = det.to_frame()
type(det)
# Out:
# pandas.core.frame.DataFrame

# %%
#want detroit to be bold over the rest of the cities

# %%
final = df[['Buffalo-Niagara Falls, NY Metro Area', 'Cleveland-Elyria-Mentor, OH Metro Area', \
            'Las Vegas-Paradise, NV Metro Area', 'Orlando-Kissimmee-Sanford, FL Metro Area', \
           'Sacramento--Arden-Arcade--Roseville, CA Metro Area','Salt Lake City, UT Metro Area']]

# %%
pl.figure(figsize = (15,8))
for i in df.columns[:1]:
    pl.plot(list(df.index), df[i].convert_objects(convert_numeric=True))

pl.plot(list(det.index), det,
       linewidth = 4, color = 'k')
pl.legend()
pl.title('Urban Density as a function of Distance from City Center')
pl.xlabel('Miles from City Center')
pl.ylabel('People per Square Mile')
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()

# %%
pl.figure(figsize = (15,8))
for i in final.columns:
    pl.plot(list(final.index), final[i].convert_objects(convert_numeric=True))

pl.plot(list(det.index), det,
       linewidth = 4, color = 'k')
pl.legend()
pl.title('Urban Density as a function of Distance from City Center')
pl.xlabel('Miles from City Center')
pl.ylabel('People per Square Mile')
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
